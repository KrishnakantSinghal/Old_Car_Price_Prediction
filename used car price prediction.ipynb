# %% [markdown]
# # USED CAR PRICE PREDICTION

# %% [markdown]
# ## importing essential libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder as lec
import joblib

# %% [markdown]
# ## Loading Datasets

# %%
train_df = pd.read_csv('C:\\codes\\ML Projects\\Car Price Prediction\\DataSets\\train.csv')

# %%
train_df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First   26.6 kmpl   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [6019 rows x 12 columns]

# %%
kmkg = 0
kmpl = 0
for i in train_df['Mileage']:
    if str(i).endswith("km/kg"):
        kmkg+=1
    elif str(i).endswith("kmpl"):
        kmpl+=1
print('The number of rows with Km/Kg : {} '.format(kmkg))
print('The number of rows with Kmpl : {} '.format(kmpl))
# Out:
# The number of rows with Km/Kg : 65
# The number of rows with Kmpl : 5952

# %%
CC = 0
for i in train_df['Engine']:
    if str(i).endswith("CC"):
        CC+=1
print('The number of rows with CC : {} '.format(CC))
# Out:
# The number of rows with CC : 5983

# %%
bhp = 0
for i in train_df['Power']:
    if str(i).endswith("bhp"):
        bhp+=1
print('The number of rows with bhp : {} '.format(bhp))
# Out:
# The number of rows with bhp : 5876

# %%
train_df = train_df[train_df.Mileage.str.contains("kmpl", na = False)]
train_df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First   26.6 kmpl   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [5952 rows x 12 columns]

# %%
train_df = train_df[train_df.Power.str.contains("bhp", na = False)]
train_df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First   26.6 kmpl   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [5810 rows x 12 columns]

# %%
train_df = train_df[train_df.Engine.str.contains("CC", na = False)]
train_df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First   26.6 kmpl   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [5810 rows x 12 columns]

# %%
kmkg = 0
kmpl = 0
for i in train_df['Mileage']:
    if str(i).endswith("km/kg"):
        kmkg+=1
    elif str(i).endswith("kmpl"):
        kmpl+=1
print('The number of rows with Km/Kg : {} '.format(kmkg))
print('The number of rows with Kmpl : {} '.format(kmpl))

CC = 0
for i in train_df['Engine']:
    if str(i).endswith("CC"):
        CC+=1
print('The number of rows with CC : {} '.format(CC))

bhp = 0
for i in train_df['Power']:
    if str(i).endswith("bhp"):
        bhp+=1
print('The number of rows with bhp : {} '.format(bhp))
# Out:
# The number of rows with Km/Kg : 0
# The number of rows with Kmpl : 5810
# The number of rows with CC : 5810
# The number of rows with bhp : 5810

# %%
train_df['Mileage'] = train_df.Mileage.str.replace(" kmpl", "")
train_df['Power'] = train_df.Power.str.replace(" bhp", "")
train_df['Engine'] = train_df.Engine.str.replace(" CC", "")

# %%
train_df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type Mileage Engine  Power  Seats  Price
# 0          CNG       Manual      First    26.6    998  58.16    5.0   1.75
# 1       Diesel       Manual      First   19.67   1582  126.2    5.0  12.50
# 2       Petrol       Manual      First    18.2   1199   88.7    5.0   4.50
# 3       Diesel       Manual      First   20.77   1248  88.76    7.0   6.00
# 4       Diesel    Automatic     Second    15.2   1968  140.8    5.0  17.74
# ...        ...          ...        ...     ...    ...    ...    ...    ...
# 6014    Diesel       Manual      First    28.4   1248     74    5.0   4.75
# 6015    Diesel       Manual      First    24.4   1120     71    5.0   4.00
# 6016    Diesel       Manual     Second    14.0   2498    112    8.0   2.90
# 6017    Petrol       Manual      First    18.9    998   67.1    5.0   2.65
# 6018    Diesel       Manual      First   25.44    936   57.6    5.0   2.50
#
# [5810 rows x 12 columns]

# %%
train_df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                2
# Price                0
# dtype: int64

# %%
train_df = train_df.dropna(subset = ['Seats'])

# %%
le = lec()

# %%
train_df['Fuel_Type'] = le.fit_transform(train_df['Fuel_Type'])
train_df['Transmission'] = le.fit_transform(train_df['Transmission'])
train_df['Owner_Type'] = le.fit_transform(train_df['Owner_Type'])
# Out:
# <ipython-input-17-b54c20dee4d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Fuel_Type'] = le.fit_transform(train_df['Fuel_Type'])
# <ipython-input-17-b54c20dee4d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Transmission'] = le.fit_transform(train_df['Transmission'])
# <ipython-input-17-b54c20dee4d2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Owner_Type'] = le.fit_transform(train_df['Owner_Type'])

# %%
train_df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#       Fuel_Type  Transmission  Owner_Type Mileage Engine  Power  Seats  Price
# 0             0             1           0    26.6    998  58.16    5.0   1.75
# 1             1             1           0   19.67   1582  126.2    5.0  12.50
# 2             2             1           0    18.2   1199   88.7    5.0   4.50
# 3             1             1           0   20.77   1248  88.76    7.0   6.00
# 4             1             0           2    15.2   1968  140.8    5.0  17.74
# ...         ...           ...         ...     ...    ...    ...    ...    ...
# 6014          1             1           0    28.4   1248     74    5.0   4.75
# 6015          1             1           0    24.4   1120     71    5.0   4.00
# 6016          1             1           2    14.0   2498    112    8.0   2.90
# 6017          2             1           0    18.9    998   67.1    5.0   2.65
# 6018          1             1           0   25.44    936   57.6    5.0   2.50
#
# [5808 rows x 12 columns]

# %%
train_df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
train_df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int32
# Transmission           int32
# Owner_Type             int32
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# dtype: object

# %%
train_df['Mileage'] = train_df.Mileage.astype('float32')
train_df['Engine'] = train_df.Engine.astype('float32')
train_df['Power'] = train_df['Power'].astype(str).astype('float32')
train_df['Seats'] = train_df['Seats'].astype('float64').astype('float32')
train_df['Price'] = train_df['Price'].astype('float64').astype('float32')
train_df['Power'].isnull().sum()
# Out:
# <ipython-input-21-1312026d3cf2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Mileage'] = train_df.Mileage.astype('float32')
# <ipython-input-21-1312026d3cf2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Engine'] = train_df.Engine.astype('float32')
# <ipython-input-21-1312026d3cf2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Power'] = train_df['Power'].astype(str).astype('float32')
# <ipython-input-21-1312026d3cf2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Seats'] = train_df['Seats'].astype('float64').astype('float32')
# <ipython-input-21-1312026d3cf2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Price'] = train_df['Price'].astype('float64').astype('float32')
# 0

# %%
train_df.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
train_df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
train_df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int32
# Transmission           int32
# Owner_Type             int32
# Mileage              float32
# Engine               float32
# Power                float32
# Seats                float32
# Price                float32
# dtype: object

# %%
train_df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
train_df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int32
# Transmission           int32
# Owner_Type             int32
# Mileage              float32
# Engine               float32
# Power                float32
# Seats                float32
# Price                float32
# dtype: object

# %%
train_df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#       Fuel_Type  Transmission  Owner_Type    Mileage  Engine       Power  \
# 0             0             1           0  26.600000   998.0   58.160000
# 1             1             1           0  19.670000  1582.0  126.199997
# 2             2             1           0  18.200001  1199.0   88.699997
# 3             1             1           0  20.770000  1248.0   88.760002
# 4             1             0           2  15.200000  1968.0  140.800003
# ...         ...           ...         ...        ...     ...         ...
# 6014          1             1           0  28.400000  1248.0   74.000000
# 6015          1             1           0  24.400000  1120.0   71.000000
# 6016          1             1           2  14.000000  2498.0  112.000000
# 6017          2             1           0  18.900000   998.0   67.099998
# 6018          1             1           0  25.440001   936.0   57.599998
#
#       Seats  Price
# 0       5.0   1.75
# 1       5.0  12.50
# 2       5.0   4.50
# 3       7.0   6.00
# 4       5.0  17.74
# ...     ...    ...
# 6014    5.0   4.75
# 6015    5.0   4.00
# 6016    8.0   2.90
# 6017    5.0   2.65
# 6018    5.0   2.50
#
# [5808 rows x 12 columns]

# %%
train_df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int32
# Transmission           int32
# Owner_Type             int32
# Mileage              float32
# Engine               float32
# Power                float32
# Seats                float32
# Price                float32
# dtype: object

# %%
train_df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
X = train_df.drop(['Price', 'Name', 'Location'], axis = 1)
y = train_df['Price']

# %% [markdown]
# ## Spliting out dataframe into train and test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.1, random_state = 51)

# %%
print("Size of X_train: ", X_train.shape)
print("Size of X_test: ", X_test.shape)
print("Size of y_train: ", y_train.shape)
print("Size of y_test: ", X_test.shape)
# Out:
# Size of X_train:  (5227, 9)
# Size of X_test:  (581, 9)
# Size of y_train:  (5227,)
# Size of y_test:  (581, 9)

# %% [markdown]
# ### Feature Scaling of Data

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.fit_transform(X_test)

# %% [markdown]
# ## Random forest Regressor

# %%
# Creating Model using Random Forest Regression

from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(n_estimators = 50, criterion = 'mse', random_state = 543)
rf_reg.fit(X_train, y_train)
rf_reg.score(X_test, y_test)
# Out:
# 0.9101946969312479

# %% [markdown]
# ## Random forest regressor for feature scaled data

# %%
rf_reg_fs = RandomForestRegressor(n_estimators = 50, criterion = 'mse', random_state = 432)
rf_reg_fs.fit(X_train_sc, y_train)
rf_reg_fs.score(X_test_sc, y_test)
# Out:
# 0.8923185985499259

# %% [markdown]
# ## DecisionTree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt_reg = DecisionTreeRegressor(criterion = 'mse', random_state=432)
dt_reg.fit(X_train, y_train)
dt_reg.score(X_test, y_test)
# Out:
# 0.8112280763290491

# %% [markdown]
# ### We will prefer Random Forest Regressor without using feature scaled data because it gives more accuracy (91.01 %)

# %%
model = joblib.dump(rf_reg ,'C:\\codes\\ML Projects\\Car Price Prediction\\ucpp_model')

# %%
pred = joblib.load('C:\\codes\\ML Projects\\Car Price Prediction\\ucpp_model')

# %% [markdown]
# ## Predicting Values Using our Test data

# %%
pred.predict(X_test)
# Out:
# array([ 6.01680002, 17.92320007,  2.31919999,  7.58819999, 14.19520006,
#        10.38819993,  5.30179999,  6.72500012,  5.55799993, 29.36040012,
